# %% [markdown]
# Import modules

# %%
# Imports - these provided for you. Do not import any other packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import operator

# %% [markdown]
# Loading in the data

# %%
db_movies = pd.read_csv('./IMDB-Movie-Data.csv')

# %%
#Isolate desired variables and eliminate rows with no rating
db_movies = db_movies[['Title','Genre','Rating','Metascore']]
db_movies = db_movies.dropna()

#Add new variables derived from Rating and Metascore
db_movies['Metascore/10'] = db_movies['Metascore']/10
db_movies['Difference'] = db_movies['Rating'] - db_movies['Metascore/10']

# %%
print(db_movies.shape)
db_movies.head()
# Out:
# (936, 6)
#                      Title                     Genre  Rating  Metascore  \
# 0  Guardians of the Galaxy   Action,Adventure,Sci-Fi     8.1       76.0
# 1               Prometheus  Adventure,Mystery,Sci-Fi     7.0       65.0
# 2                    Split           Horror,Thriller     7.3       62.0
# 3                     Sing   Animation,Comedy,Family     7.2       59.0
# 4            Suicide Squad  Action,Adventure,Fantasy     6.2       40.0
#
#    Metascore/10  Difference
# 0           7.6         0.5
# 1           6.5         0.5
# 2           6.2         1.1
# 3           5.9         1.3
# 4           4.0         2.2

# %% [markdown]
# Identify genres and create dataframes of movies in each genre

# %%
#Returns a list of string labels for genres used
def getGenres(dataframe):
    genres = list()
    genreCol = dataframe['Genre']
    
    #Get the entry from the column
    for genreEnt in genreCol:
        #Split and parse strings of genre
        genreEntries = genreEnt.split(',')
        for genre in genreEntries:
            #check if it is in the list
            if not(any(genre in listEntry for listEntry in genres)):
                #Add to list if not included yet
                genres.append(genre)
    return genres

# %%
def hasGenre(row,genre):
    return genre in row['Genre']

# %% [markdown]
# Bar chart of genre frequency. Movies may be duplicated across genres

# %%
#Get the genres used and generate an empty list
genreList = getGenres(db_movies)
genreFreq = list()

#Fill the requency dictionary genreFreq
for genre in genreList:
    freq = 0
    for index, row in db_movies.iterrows():
        if (hasGenre(row,genre)):
            freq += 1
    genreFreq.append((genre,freq))

#Sort dictionary by key into a tuple list
genreFreq.sort(key = lambda tup:tup[1],reverse=True)

# %%
#Plot genreFreq as a bar chart
x = range(len(genreFreq))
x_label, y = zip(*genreFreq)

ax = plt.axes()

plt.bar(x, y, align='center',linewidth=0)
plt.xticks(x,x_label, rotation='vertical')
plt.title('Number of Films in a Genre')
ax.spines['right'].set_linewidth(0)
ax.spines['top'].set_linewidth(0)
plt.show()

# %% [markdown]
# Create new dataframes using the top five genres

# %%
def getGenreMovies(movies,genreList):
    movieTables = {}
    for genre in genreList:
        movieTables[genre] = movies.loc[movies['Genre'].str.contains(genre)]
    return movieTables

# %%
movieTb = getGenreMovies(db_movies,genreList)

# %%
#Get the correlation coefficients between ratings
genreCorr = list()
for genre in genreList:
    genreCorr.append((genre,movieTb[genre].corr()['Rating']['Metascore']))

# %%
[tup for tup in genreCorr if abs(tup[1]) < 0.5]
# Out:
# [('Horror', 0.4907297965929032),
#  ('Music', 0.475652879054996),
#  ('Biography', 0.35940753272590187)]

# %% [markdown]
# Plot histogram of differences in rating in movies for each genre

# %%
#Merge acion,comedy,and horror films
#dumFilms = 

#Merge drama and historical films
branFilms = movieTb['Drama'].combine_first(movieTb['History'])




#plt.title('Difference in IMDb User Rating minus Metacritic Rating/10')
#plt.ylabel('Frequency')


#plt.show()
branFilms
# Out:
#                               Title                   Genre_x  Rating_x  \
# 0                        La La Land        Comedy,Drama,Music       8.3
# 1                        Passengers   Adventure,Drama,Romance       7.0
# 2                    Hidden Figures   Biography,Drama,History       7.8
# 3                          Colossal       Action,Comedy,Drama       6.4
# 4                     Hacksaw Ridge   Biography,Drama,History       8.2
# 5                              Lion           Biography,Drama       8.1
# 6                           Arrival      Drama,Mystery,Sci-Fi       8.0
# 7                              Gold  Adventure,Drama,Thriller       6.7
# 8             Manchester by the Sea                     Drama       7.9
# 9                    Hounds of Love        Crime,Drama,Horror       6.7
# 10                 Assassin's Creed    Action,Adventure,Drama       5.9
# 11                Nocturnal Animals            Drama,Thriller       7.5
# 12                     Interstellar    Adventure,Drama,Sci-Fi       8.6
# 13                        Moonlight                     Drama       7.5
# 14                      The Founder   Biography,Drama,History       7.2
# 15                        Lowriders                     Drama       6.3
# 16                      Miss Sloane            Drama,Thriller       7.3
# 17                    The Last Face                     Drama       3.7
# 18                     Mother's Day              Comedy,Drama       5.6
# 19                  The Dark Knight        Action,Crime,Drama       9.0
# 20                          Silence   Adventure,Drama,History       7.3
# 21                    Me Before You             Drama,Romance       7.4
# 22                     Their Finest      Comedy,Drama,Romance       7.0
# 23                            Sully           Biography,Drama       7.5
# 24            The Girl on the Train       Crime,Drama,Mystery       6.5
# 25             Fifty Shades of Grey    Drama,Romance,Thriller       4.1
# 26                     The Prestige      Drama,Mystery,Sci-Fi       8.5
# 27                     Patriots Day    Drama,History,Thriller       7.4
# 28                        Wakefield                     Drama       7.5
# 29                Deepwater Horizon     Action,Drama,Thriller       7.2
# ..                              ...                       ...       ...
# 445                       If I Stay       Drama,Fantasy,Music       6.8
# 446                      The Ticket                     Drama       5.4
# 447                           Super              Comedy,Drama       6.8
# 448         The Siege of Jadotville     Action,Drama,Thriller       7.3
# 449      The Twilight Saga: Eclipse   Adventure,Drama,Fantasy       4.9
# 450                      King Cobra               Crime,Drama       5.6
# 451  Me and Earl and the Dying Girl              Comedy,Drama       7.8
# 452                 The Descendants              Comedy,Drama       7.3
# 453              Sex and the City 2      Comedy,Drama,Romance       4.3
# 454             The Kings of Summer    Adventure,Comedy,Drama       7.2
# 455                    End of Watch      Crime,Drama,Thriller       7.7
# 456                  3 Days to Kill     Action,Drama,Thriller       6.2
# 457             Lucky Number Slevin       Crime,Drama,Mystery       7.8
# 458                          Trance       Crime,Drama,Mystery       7.0
# 459                 Into the Forest     Drama,Sci-Fi,Thriller       5.9
# 460           The Other Boleyn Girl   Biography,Drama,History       6.7
# 461                         Custody                     Drama       6.9
# 462                    Rock of Ages      Comedy,Drama,Musical       5.9
# 463                  Queen of Katwe     Biography,Drama,Sport       7.4
# 464                     Dark Places    Drama,Mystery,Thriller       6.2
# 465  It's Only the End of the World                     Drama       7.0
# 466              The Skin I Live In            Drama,Thriller       7.6
# 467            Miracles from Heaven    Biography,Drama,Family       7.0
# 468                           Annie       Comedy,Drama,Family       5.3
# 469             Across the Universe     Drama,Fantasy,Musical       7.4
# 470                    Endless Love             Drama,Romance       6.3
# 471                Taare Zameen Par        Drama,Family,Music       8.5
# 472            Secret in Their Eyes       Crime,Drama,Mystery       6.2
# 473          Step Up 2: The Streets       Drama,Music,Romance       6.2
# 474                      Anthropoid                       NaN       NaN
#
#      Metascore_x  Metascore/10_x  Difference_x                     Genre_y  \
# 0           93.0             9.3          -1.0                         NaN
# 1           41.0             4.1           2.9                         NaN
# 2           74.0             7.4           0.4     Biography,Drama,History
# 3           70.0             7.0          -0.6                         NaN
# 4           71.0             7.1           1.1     Biography,Drama,History
# 5           69.0             6.9           1.2                         NaN
# 6           81.0             8.1          -0.1                         NaN
# 7           49.0             4.9           1.8                         NaN
# 8           96.0             9.6          -1.7                         NaN
# 9           72.0             7.2          -0.5                         NaN
# 10          36.0             3.6           2.3                         NaN
# 11          67.0             6.7           0.8                         NaN
# 12          74.0             7.4           1.2                         NaN
# 13          99.0             9.9          -2.4                         NaN
# 14          66.0             6.6           0.6     Biography,Drama,History
# 15          57.0             5.7           0.6                         NaN
# 16          64.0             6.4           0.9                         NaN
# 17          16.0             1.6           2.1                         NaN
# 18          18.0             1.8           3.8                         NaN
# 19          82.0             8.2           0.8                         NaN
# 20          79.0             7.9          -0.6     Adventure,Drama,History
# 21          51.0             5.1           2.3                         NaN
# 22          76.0             7.6          -0.6                         NaN
# 23          74.0             7.4           0.1                         NaN
# 24          48.0             4.8           1.7                         NaN
# 25          46.0             4.6          -0.5                         NaN
# 26          66.0             6.6           1.9                         NaN
# 27          69.0             6.9           0.5      Drama,History,Thriller
# 28          61.0             6.1           1.4                         NaN
# 29          68.0             6.8           0.4                         NaN
# ..           ...             ...           ...                         ...
# 445         46.0             4.6           2.2                         NaN
# 446         52.0             5.2           0.2                         NaN
# 447         50.0             5.0           1.8                         NaN
# 448         83.0             8.3          -1.0                         NaN
# 449         58.0             5.8          -0.9                         NaN
# 450         48.0             4.8           0.8                         NaN
# 451         74.0             7.4           0.4                         NaN
# 452         84.0             8.4          -1.1                         NaN
# 453         27.0             2.7           1.6                         NaN
# 454         61.0             6.1           1.1                         NaN
# 455         68.0             6.8           0.9                         NaN
# 456         40.0             4.0           2.2                         NaN
# 457         53.0             5.3           2.5                         NaN
# 458         61.0             6.1           0.9                         NaN
# 459         59.0             5.9           0.0                         NaN
# 460         50.0             5.0           1.7     Biography,Drama,History
# 461         72.0             7.2          -0.3                         NaN
# 462         47.0             4.7           1.2                         NaN
# 463         73.0             7.3           0.1                         NaN
# 464         39.0             3.9           2.3                         NaN
# 465         48.0             4.8           2.2                         NaN
# 466         70.0             7.0           0.6                         NaN
# 467         44.0             4.4           2.6                         NaN
# 468         33.0             3.3           2.0                         NaN
# 469         56.0             5.6           1.8                         NaN
# 470         30.0             3.0           3.3                         NaN
# 471         42.0             4.2           4.3                         NaN
# 472         45.0             4.5           1.7                         NaN
# 473         50.0             5.0           1.2                         NaN
# 474          NaN             NaN           NaN  Biography,History,Thriller
#
#      Rating_y  Metascore_y  Metascore/10_y  Difference_y
# 0         NaN          NaN             NaN           NaN
# 1         NaN          NaN             NaN           NaN
# 2         7.8         74.0             7.4           0.4
# 3         NaN          NaN             NaN           NaN
# 4         8.2         71.0             7.1           1.1
# 5         NaN          NaN             NaN           NaN
# 6         NaN          NaN             NaN           NaN
# 7         NaN          NaN             NaN           NaN
# 8         NaN          NaN             NaN           NaN
# 9         NaN          NaN             NaN           NaN
# 10        NaN          NaN             NaN           NaN
# 11        NaN          NaN             NaN           NaN
# 12        NaN          NaN             NaN           NaN
# 13        NaN          NaN             NaN           NaN
# 14        7.2         66.0             6.6           0.6
# 15        NaN          NaN             NaN           NaN
# 16        NaN          NaN             NaN           NaN
# 17        NaN          NaN             NaN           NaN
# 18        NaN          NaN             NaN           NaN
# 19        NaN          NaN             NaN           NaN
# 20        7.3         79.0             7.9          -0.6
# 21        NaN          NaN             NaN           NaN
# 22        NaN          NaN             NaN           NaN
# 23        NaN          NaN             NaN           NaN
# 24        NaN          NaN             NaN           NaN
# 25        NaN          NaN             NaN           NaN
# 26        NaN          NaN             NaN           NaN
# 27        7.4         69.0             6.9           0.5
# 28        NaN          NaN             NaN           NaN
# 29        NaN          NaN             NaN           NaN
# ..        ...          ...             ...           ...
# 445       NaN          NaN             NaN           NaN
# 446       NaN          NaN             NaN           NaN
# 447       NaN          NaN             NaN           NaN
# 448       NaN          NaN             NaN           NaN
# 449       NaN          NaN             NaN           NaN
# 450       NaN          NaN             NaN           NaN
# 451       NaN          NaN             NaN           NaN
# 452       NaN          NaN             NaN           NaN
# 453       NaN          NaN             NaN           NaN
# 454       NaN          NaN             NaN           NaN
# 455       NaN          NaN             NaN           NaN
# 456       NaN          NaN             NaN           NaN
# 457       NaN          NaN             NaN           NaN
# 458       NaN          NaN             NaN           NaN
# 459       NaN          NaN             NaN           NaN
# 460       6.7         50.0             5.0           1.7
# 461       NaN          NaN             NaN           NaN
# 462       NaN          NaN             NaN           NaN
# 463       NaN          NaN             NaN           NaN
# 464       NaN          NaN             NaN           NaN
# 465       NaN          NaN             NaN           NaN
# 466       NaN          NaN             NaN           NaN
# 467       NaN          NaN             NaN           NaN
# 468       NaN          NaN             NaN           NaN
# 469       NaN          NaN             NaN           NaN
# 470       NaN          NaN             NaN           NaN
# 471       NaN          NaN             NaN           NaN
# 472       NaN          NaN             NaN           NaN
# 473       NaN          NaN             NaN           NaN
# 474       7.2         59.0             5.9           1.3
#
# [475 rows x 11 columns]

# %%
stats.ttest_ind(genre_df['Difference'], db_movies['Difference'], axis=0)
# Out:
# Ttest_indResult(statistic=0.07584291345451387, pvalue=0.939560042622371)
